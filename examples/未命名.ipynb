# %%
import music21 as m21

file = '../data/albinoni1.mid'
i = m21.converter.parse(file)

# %%
list(i)
# Out:
# [<music21.stream.Part 0x7f638a3a6a90>,
#  <music21.stream.Part 0x7f638bc78f28>,
#  <music21.stream.Part 0x7f638bb25978>,
#  <music21.stream.Part 0x7f638a0eb7b8>]

# %%
list(i[0])
# Out:
# [<music21.instrument.StringInstrument 'StringInstrument'>,
#  <music21.tempo.MetronomeMark larghetto Quarter=60.0>,
#  <music21.tempo.MetronomeMark larghetto Quarter=60.0>,
#  <music21.key.Key of B- major>,
#  <music21.key.Key of B- major>,
#  <music21.meter.TimeSignature 3/4>,
#  <music21.note.Note G>,
#  <music21.note.Note G>,
#  <music21.note.Note A>,
#  <music21.note.Rest rest>,
#  <music21.note.Note B->,
#  <music21.note.Note G>,
#  <music21.note.Note G>,
#  <music21.note.Note A>,
#  <music21.note.Note B->,
#  <music21.note.Rest rest>,
#  <music21.note.Note C>,
#  <music21.note.Note B->,
#  <music21.note.Note A>,
#  <music21.note.Rest rest>,
#  <music21.note.Note B->,
#  <music21.note.Note A>,
#  <music21.note.Note G>,
#  <music21.note.Rest rest>,
#  <music21.note.Note A>,
#  <music21.note.Rest rest>,
#  <music21.note.Note G>,
#  <music21.note.Note F#>,
#  <music21.note.Note G>,
#  <music21.note.Note D>,
#  <music21.note.Note C>,
#  <music21.note.Note B->,
# ...

# %%
import midi
midi.read_midifile(file)
# Out:
# midi.Pattern(format=1, resolution=256, tracks=\
# [midi.Track(\
#   [midi.TrackNameEvent(tick=0, text='00000005', data=[48, 48, 48, 48, 48, 48, 48, 53]),
#    midi.TimeSignatureEvent(tick=0, data=[3, 2, 24, 8]),
#    midi.KeySignatureEvent(tick=0, data=[254, 0]),
#    midi.SetTempoEvent(tick=0, data=[15, 66, 64]),
#    midi.KeySignatureEvent(tick=0, data=[254, 0]),
#    midi.SetTempoEvent(tick=0, data=[15, 66, 64]),
#    midi.EndOfTrackEvent(tick=1, data=[])]),
#  midi.Track(\
#   [midi.ControlChangeEvent(tick=0, channel=4, data=[121, 0]),
#    midi.ControlChangeEvent(tick=0, channel=4, data=[64, 0]),
#    midi.ControlChangeEvent(tick=0, channel=4, data=[91, 48]),
#    midi.ControlChangeEvent(tick=0, channel=4, data=[10, 16]),
#    midi.ControlChangeEvent(tick=0, channel=4, data=[7, 100]),
#    midi.ProgramChangeEvent(tick=0, channel=4, data=[48]),
#    midi.TrackNameEvent(tick=0, text='Violin 1', data=[86, 105, 111, 108, 105, 110, 32, 49]),
# ...
